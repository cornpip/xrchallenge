# %% [markdown]
# <a href="https://colab.research.google.com/github/cornpip/xrchallenge/blob/main/gpumachine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !nvcc --version 
## 코랩 명령어 쓰는거 앞에 기호주의
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
# %cd ../content/gdrive/MyDrive/machine/xrproject/
#gdrive/MyDrive 마지막에 슬래쉬안치면 안됨
#%cd MyDrive/
# !ls
# !pwd
# Out:
# [Errno 2] No such file or directory: '../content/gdrive/MyDrive/machine/xrproject/'
# /content/gdrive/MyDrive
#  연구실    'Colab Notebooks'			 nodejsweb.zip
#  정보보안  'How to get started with Drive.pdf'	 wap
#  3-1	    machine				 xrchallenge
# /content/gdrive/My Drive
# /content/gdrive
# /content/gdrive

# %%
# !python test2.py
# Out:
# 2021-08-04 14:34:28.892452: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-08-04 14:34:31.315116: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-08-04 14:34:31.376407: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-04 14:34:31.377003: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-08-04 14:34:31.377052: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...

# %%
# !python train_traffic_light_color.py
# Out:
# 2021-08-04 14:36:36.627499: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# TensorFlow 2.5.0
# Keras 2.5.0
# tcmalloc: large alloc 3954393088 bytes == 0x5640dcee4000 @  0x7fcaec1671e7 0x7fcae076c46e 0x7fcae07bcc7b 0x7fcae076fce8 0x5640b80c8a65 0x5640b80898a9 0x5640b80fdb0a 0x5640b80f7c35 0x5640b80f7933 0x5640b81c1402 0x5640b81c177d 0x5640b81c1626 0x5640b8199313 0x5640b8198fbc 0x7fcaeaf51bf7 0x5640b8198e9a
# Images:  1843
# Labels:  1843
# Labels: Counter({3: 1296, 2: 264, 1: 142, 0: 141})
# 0: 141
# 1: 142
# 2: 264
# 3: 1296
# Class weight: {0: 13.070921985815604, 1: 12.97887323943662, 2: 6.981060606060606, 3: 1.4220679012345678}
# Loading Inception V3...
# 2021-08-04 14:48:01.846621: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# ...

# %%
# !python detect_traffic_light_color_vid.py
# Out:
# 2021-08-05 16:39:22.154220: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...
# 244817920/244817203 [==============================] - 1s 0us/step
# Model path:  /root/.keras/datasets/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8
# 2021-08-05 16:39:27.963414: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-08-05 16:39:28.058006: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-05 16:39:28.058947: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %%
# !python detect_traffic_light_color_img.py
# Out:
# 2021-08-04 15:54:10.345753: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-08-04 15:54:11.820779: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-08-04 15:54:11.851197: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-04 15:54:11.851848: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-08-04 15:54:11.851904: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...
